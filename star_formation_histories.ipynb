# %%
import sfh
import matplotlib.pyplot as plt

# %%
# Generate a random SFH
weights = sfh.gen_rand_sfh()

# Initialise galaxy
galaxy = sfh.SFH(weights)

# Get the final spectrum
wav, s = galaxy.final_spectrum()
# Out:
# Generating random SFH...
# Random SFH generated: [0.21737903 0.05486594 0.12388457 0.38535955 0.21851091]
# Checking inputs...
# Initialising spectra...
# Initialising binning...
# Initialisation complete!
# Compiling spectrum...
# Final spectrum compiled!

# %%
plt.plot(wav, s)
plt.xlim(3500,7500)

print(weights)
# Out:
# [0.21737903 0.05486594 0.12388457 0.38535955 0.21851091]
