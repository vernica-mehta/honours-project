# %%
from cornerplot import Cornerplots
from astropy.io import fits
import numpy as np

# %%
f = fits.getdata("/avatar/vmehta/sfh_500_20260205_112842/sfh_500_20260205_112842_labels.fits")
f
# Out:
# array([[3.67777416e-02, 3.63247324e-01, 4.04073176e-02, ...,
#         3.98543323e-01, 3.71712587e-04, 7.89758772e-06],
#        [8.86552132e-02, 1.13273687e-01, 1.49778728e-01, ...,
#         1.33179983e-02, 1.62439391e-01, 6.79585769e-02],
#        [5.91562011e-02, 3.25717349e-02, 2.06684677e-01, ...,
#         1.64173644e-02, 7.94288241e-02, 4.16379255e-02],
#        ...,
#        [1.19752984e-01, 1.29160354e-01, 6.18926492e-02, ...,
#         4.47377814e-02, 1.63864304e-01, 9.62455470e-02],
#        [1.53624783e-02, 1.54151995e-02, 1.02916796e-01, ...,
#         6.95739425e-02, 1.99667225e-01, 2.66533660e-03],
#        [1.18398806e-01, 9.06494727e-02, 1.58904491e-01, ...,
#         6.66237181e-02, 8.81262829e-02, 8.54918827e-02]],
#       shape=(500, 10), dtype='>f8')

# %%
cp = Cornerplots(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 cp.plot(f)
#
# TypeError: Cornerplots.plot() missing 1 required positional argument: 'datadict'
